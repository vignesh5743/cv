# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('tree.jpeg', cv2.IMREAD_GRAYSCALE)

negative_image = 255 - image

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(image, cmap='gray')
plt.subplot(1, 2, 2)
plt.title("Negative Image")
plt.imshow(negative_image, cmap='gray')
plt.show()

# %%
c = 255 / np.log(1 + np.max(image))
log_image = c * np.log(1 + image)

log_image = np.array(log_image, dtype=np.uint8)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(image, cmap='gray')
plt.subplot(1, 2, 2)
plt.title("Log Transformed Image")
plt.imshow(log_image, cmap='gray')
plt.show()
# Out:
# C:\Users\harih\AppData\Local\Temp\ipykernel_8260\1400570605.py:2: RuntimeWarning: divide by zero encountered in log
#   log_image = c * np.log(1 + image)

# %%
gamma = 2.0  # You can change the value of gamma for different results
c = 255 / (np.max(image) ** gamma)
gamma_image = c * (image ** gamma)

gamma_image = np.array(gamma_image, dtype=np.uint8)

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title("Original Image")
plt.imshow(image, cmap='gray')
plt.subplot(1, 2, 2)
plt.title("Gamma Transformed Image")
plt.imshow(gamma_image, cmap='gray')
plt.show()
